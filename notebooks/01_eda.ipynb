# %%
import nfl_data_py as nfl
import pandas as pd
import numpy as np

# %%
seasons = [2020, 2021, 2022, 2023, 2024]
games = nfl.import_schedules(seasons)
player_stats = nfl.import_weekly_data(seasons)
next_gen = nfl.import_ngs_data(stat_type = 'passing', years=seasons)
# Out:
# Downcasting floats.

# %%
next_gen.head()
# WEEK 0 = FULL SEASON
# Out:
#       season season_type  week player_display_name player_position team_abbr  \
# 2302    2020         REG     0      Justin Herbert              QB       LAC
# 2303    2020         REG     0        Nick Mullens              QB        SF
# 2304    2020         REG     0      Baker Mayfield              QB       CLE
# 2305    2020         REG     0    Ryan Fitzpatrick              QB       MIA
# 2306    2020         REG     0          Joe Burrow              QB       CIN
#
#       avg_time_to_throw  avg_completed_air_yards  avg_intended_air_yards  \
# 2302           2.687305                 5.216843                7.502345
# 2303           2.631663                 5.621564                6.633950
# 2304           3.050420                 7.357672                9.036446
# 2305           2.380628                 6.455301                7.887235
# 2306           2.648601                 5.727538                8.782087
#
#       avg_air_yards_differential  ...  completion_percentage  \
# ...
